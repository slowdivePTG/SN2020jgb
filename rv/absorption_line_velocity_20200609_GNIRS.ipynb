# %%
# %load_ext autoreload
# %autoreload 2

# %%
import absorption_line_vel as vel
from absorption_line_vel import SpectrumSN_Lines, AbsorbLine

# read spec data
z = 0.0307
spec = '../spectroscopy/ZTF20aayhacx_20200609_GNIRS.ascii'
Spec1 = SpectrumSN_Lines(spec, z)

# %% [markdown]
# # 20200529_Lick_3-m

# %% [markdown]
# ## Si II 6355

# %%
Spec1.plot_line_region(9500, 10500)

# %%
Spec1.add_line('HeI_10830', 9500, 10300, lines=[10830])
# Out:
# 214 points within 9500.00 and 10300.00 angstroms.

# %%
Spec1.line['HeI_10830'].LS_estimator(guess=(1, 1, -25000, 15, -2000))
# Out:
# LS estimation:
# Velocity pvf: -26469 km/s

# %%
Spec1.add_line('MgII_10927', 9500, 10300, lines=[10927])
# Out:
# 214 points within 9500.00 and 10300.00 angstroms.

# %%
Spec1.line['MgII_10927'].LS_estimator(guess=(1, 1, -25000, 15, -2000))
# Out:
# LS estimation:
# Velocity pvf: -29119 km/s
